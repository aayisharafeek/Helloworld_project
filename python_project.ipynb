# %%
import random
print('WELCOME TO GAME ZONE ')
Ans=input('Wanna play Rock Paper Scissor (Y/N) ')
if Ans.upper()=='Y':
  Data=['R','P','S']
  def playtime():
    print('**** RULES ****')
    print('1.Rock wins against Scissors')
    print('2.Paper wins against Rock')
    print('3.Scissors wins against Paper')
    print('Total Five chances ')
    print('All the best')
    print('The game begins........')
    print('\n'*5)
    print('Choices =',Data)
    n=5
    user=0
    python=0
    for i in range (5):
      user_choice=input('My Choice is: ')
      python_choice=random.choice(Data)
      print('Python Choice is :',python_choice)
      if user_choice.upper() == python_choice.upper():
        print('\n'*1)
        print('Me =',user)
        print('Python =',python)
        print('\n'*1)
      else:
        if user_choice.upper() == 'S'and python_choice.upper() =='P':
          user+=1
        elif user_choice.upper() == 'P' and python_choice.upper() =='R':
          user+=1
        elif user_choice.upper() =='R' and python_choice.upper() =='S':
           user+=1
        else:
          python+=1
        print('\n'*1)
        print('Me =',user)
        print('Python =',python) 
        print('\n'*1)
    print('\n'*2)
    print('GAME OVER')
    print('*'*10)
    print('TOTAL SCORE')
    print('Me =', user)
    print('Python =', python)
    if user > python:
      print('***** CONGRATS ******')
      print('***** YOU ARE THE WINNER *****')
    elif python > user:
      print('***** CONGRATS *****')
      print('***** PYTHON IS THE WINNER *****')
    else:
      print('Its a Tie')
    again=input('Play again Y/N ')
    if again.upper()=='Y':
      playtime()
    else:
      print('Thank you for playing ....')
  playtime()
else:
  print('Thank you...')
# Out:
# WELCOME TO GAME ZONE
# Wanna play Rock Paper Scissor (Y/N) y
# **** RULES ****
# 1.Rock wins against Scissors
# 2.Paper wins against Rock
# 3.Scissors wins against Paper
# Total Five chances
# All the best
# The game begins........
#
#
#
#
#
#
# Choices = ['R', 'P', 'S']
# My Choice is: p
# Python Choice is : S
#
#
# Me = 0
# Python = 1
#
#
# My Choice is: s
# Python Choice is : R
#
#
# Me = 0
# Python = 2
#
#
# My Choice is: s
# Python Choice is : R
#
#
# Me = 0
# Python = 3
#
#
# My Choice is: r
# Python Choice is : S
#
#
# Me = 1
# Python = 3
#
#
# My Choice is: p
# Python Choice is : P
#
#
# Me = 1
# Python = 3
#
#
#
#
#
# GAME OVER
# **********
# TOTAL SCORE
# Me = 1
# Python = 3
# ***** CONGRATS *****
# ***** PYTHON IS THE WINNER *****
# Play again Y/N y
# **** RULES ****
# 1.Rock wins against Scissors
# 2.Paper wins against Rock
# 3.Scissors wins against Paper
# Total Five chances
# All the best
# The game begins........
#
#
#
#
#
#
# Choices = ['R', 'P', 'S']
# ...
